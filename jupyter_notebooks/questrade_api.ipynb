# %% [markdown]
# https://pypi.org/project/questrade-api/

# %%
import sys
import os
#from questrade_api import Questrade
from questrade_api.questrade import Questrade
import pandas as pd
#import datetime
from datetime import datetime, timedelta
from pytz import timezone

# %%
# SET TOKEN PATH

def set_token_path():
    global TOKEN_PATH
    print('SET QUESTRADE ACCOUNT')
    print('1 - Corporate 1')
    print('2 - Corporate 2')
    print('3 - Personsal')
    account_name_number = input('Choose Account : (1-3)')
    if account_name_number == '1':
        account_name= 'corporate1'
    elif account_name_number == '2':
        account_name = 'corporate2'
    elif account_name_number == '3':
        account_name = 'personal'
    else:
        account_name = 'dumbass'
    if account_name:
        print('account_name : ',account_name)
    TOKEN_PATH = 'token-'+account_name+"-questrade.json"
    print(TOKEN_PATH)
    return(TOKEN_PATH)
    
set_token_path()
print('TOKEN_PATH = ',TOKEN_PATH)
# Out:
# SET QUESTRADE ACCOUNT
# 1 - Corporate 1
# 2 - Corporate 2
# 3 - Personsal
# Choose Account : (1-3) 1
# account_name :  corporate1
# token-corporate1-questrade.json
# TOKEN_PATH =  token-corporate1-questrade.json

# %%
# INTIALLY SET ACCESS TOKEN

def set_access_token():
    token = input('Refresh Token: ')
    q = Questrade(refresh_token=token)
    print('token :',token)
    print(q)
    return()

set_access_token()
# Out:
# Refresh Token:  ePIBkt-bler7dyg-FRS_i9iwGnmog4iJ0
# token : ePIBkt-bler7dyg-FRS_i9iwGnmog4iJ0
# <questrade_api.questrade.Questrade object at 0x00000268D2DDA490>
# ()

# %%
# AFTER TOKEN HAS BEEN REGISTER USE THIS

def set_refresh_token():
    q = Questrade()
    print(q)
    return()
    
set_refresh_token()
# Out:
# <questrade_api.questrade.Questrade object at 0x00000268EBA33C70>
# ()

# %%
# TIME
def server_time():
    st=q.time
    server_time = st.get('time')
    return server_time

def time_name():
    timename = server_time().replace(':','-')
    return timename

def start_date(days_back):
    date_part = server_time()[:10]
    rest_of_it = server_time()[10:]
    date_format = "%Y-%m-%d"
    date_object = datetime.strptime(date_part, date_format)
    tdelta = timedelta(days=days_back)
    last_month_date_obj = date_object - tdelta
    last_month = last_month_date_obj.strftime(date_format)
    start_date = last_month + rest_of_it
    return(start_date)
    
    
print(server_time())
print(time_name())
start_date(30)
print(start_date(30))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# C:\Users\FEARA_~1\AppData\Local\Temp/ipykernel_170140/1669465866.py in <module>
#      21
#      22
# ---> 23 print(server_time())
#      24 print(time_name())
#      25 start_date(30)
#
# C:\Users\FEARA_~1\AppData\Local\Temp/ipykernel_170140/1669465866.py in server_time()
#       1 # TIME
#       2 def server_time():
# ----> 3     st=q.time
#       4     server_time = st.get('time')
#       5     return server_time
#
# D:\dropbox\code\riskmit_questrade\questrade_api\questrade.py in time(self)
#      79     @property
#      80     def time(self):
# ---> 81         return self.__get(self.config['API']['time'])
#      82
#      83     @property
#
# D:\dropbox\code\riskmit_questrade\questrade_api\questrade.py in __get(self, url, params)
#      40
#      41     def __get(self, url, params=None):
# ---> 42         req = self.__build_get_req(url, params)
#      43         req.add_header(
#      44             'Authorization',
#
# D:\dropbox\code\riskmit_questrade\questrade_api\questrade.py in __build_get_req(self, url, params)
#      37             return urllib.request.Request(url)
#      38         else:
# ---> 39             return urllib.request.Request(self.__base_url + url)
#      40
#      41     def __get(self, url, params=None):
#
# D:\dropbox\code\riskmit_questrade\questrade_api\questrade.py in __base_url(self)
#      30     @property
#      31     def __base_url(self):
# ---> 32         return self.auth.token['api_server'] + self.config['Settings']['Version']
#      33
#      34     def __build_get_req(self, url, params):
#
# D:\dropbox\code\riskmit_questrade\questrade_api\auth.py in token(self)
#      57
#      58     @property
# ---> 59     def token(self):
#      60         return self.__get_valid_token()
#
# D:\dropbox\code\riskmit_questrade\questrade_api\auth.py in __get_valid_token(self)
#      51             if time.time() + 60 < int(self.token_data['expires_at']):
#      52                 return self.token_data
# ---> 53             else:
#      54                 self.__refresh_token(self.token_data['refresh_token'])
#      55                 self.token_data = self.__read_token()
#
# D:\dropbox\code\riskmit_questrade\questrade_api\auth.py in __refresh_token(self, token)
#      36
#      37     def __refresh_token(self, token):
# ---> 38         req_time = int(time.time())
#      39         r = request.urlopen(self.config['Auth']['RefreshURL'].format(token))
#      40         if r.getcode() == 200:
#
# C:\Program Files\Python39\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# C:\Program Files\Python39\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     521         for processor in self.process_response.get(protocol, []):
#     522             meth = getattr(processor, meth_name)
# --> 523             response = meth(req, response)
#     524
#     525         return response
#
# C:\Program Files\Python39\lib\urllib\request.py in http_response(self, request, response)
#     630         # request was successfully received, understood, and accepted.
#     631         if not (200 <= code < 300):
# --> 632             response = self.parent.error(
#     633                 'http', request, response, code, msg, hdrs)
#     634
#
# C:\Program Files\Python39\lib\urllib\request.py in error(self, proto, *args)
#     559         if http_err:
#     560             args = (dict, 'default', 'http_error_default') + orig_args
# --> 561             return self._call_chain(*args)
#     562
#     563 # XXX probably also want an abstract factory that knows when it makes
#
# C:\Program Files\Python39\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# C:\Program Files\Python39\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     639 class HTTPDefaultErrorHandler(BaseHandler):
#     640     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     642
#     643 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 400: Bad Request

# %%
# Set file foler path for exports
filefolder = 'D:\Dropbox\- INVESTINU\- QUESTRADE_API EXPORTS\ACCOUNT 1'
#filefolder = 'D:\Dropbox\- INVESTINU\- QUESTRADE_API EXPORTS\ACCOUNT 2'
print('using :', filefolder)
# Out:
# using : D:\Dropbox\- INVESTINU\- QUESTRADE_API EXPORTS\ACCOUNT 1

# %%
# ACCOUNTS
def accounts():
    
    dict_accounts = q.accounts
    dict_accounts
    user_id = q.accounts['userId']
    print('user_id :',user_id)
    df_accounts = pd.DataFrame.from_dict(q.accounts['accounts']) #de-nest the accounts dict and make df
    display(df_accounts)
    filename = os.path.join(filefolder, '-accounts.xlsx')
    df_accounts.to_excel(filename, header=True, )
    return('success')

accounts()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# C:\Users\FEARA_~1\AppData\Local\Temp/ipykernel_170140/1975546473.py in <module>
#      12     return('success')
#      13
# ---> 14 accounts()
#
# C:\Users\FEARA_~1\AppData\Local\Temp/ipykernel_170140/1975546473.py in accounts()
#       2 def accounts():
#       3
# ----> 4     dict_accounts = q.accounts
#       5     dict_accounts
#       6     user_id = q.accounts['userId']
#
# D:\dropbox\code\riskmit_questrade\questrade_api\questrade.py in accounts(self)
#      83     @property
#      84     def accounts(self):
# ---> 85         return self.__get(self.config['API']['Accounts'])
#      86
#      87     def account_positions(self, id):
#
# D:\dropbox\code\riskmit_questrade\questrade_api\questrade.py in __get(self, url, params)
#      40
#      41     def __get(self, url, params=None):
# ---> 42         req = self.__build_get_req(url, params)
#      43         req.add_header(
#      44             'Authorization',
#
# D:\dropbox\code\riskmit_questrade\questrade_api\questrade.py in __build_get_req(self, url, params)
#      37             return urllib.request.Request(url)
#      38         else:
# ---> 39             return urllib.request.Request(self.__base_url + url)
#      40
#      41     def __get(self, url, params=None):
#
# D:\dropbox\code\riskmit_questrade\questrade_api\questrade.py in __base_url(self)
#      30     @property
#      31     def __base_url(self):
# ---> 32         return self.auth.token['api_server'] + self.config['Settings']['Version']
#      33
#      34     def __build_get_req(self, url, params):
#
# D:\dropbox\code\riskmit_questrade\questrade_api\auth.py in token(self)
#      57
#      58     @property
# ---> 59     def token(self):
#      60         return self.__get_valid_token()
#
# D:\dropbox\code\riskmit_questrade\questrade_api\auth.py in __get_valid_token(self)
#      51             if time.time() + 60 < int(self.token_data['expires_at']):
#      52                 return self.token_data
# ---> 53             else:
#      54                 self.__refresh_token(self.token_data['refresh_token'])
#      55                 self.token_data = self.__read_token()
#
# D:\dropbox\code\riskmit_questrade\questrade_api\auth.py in __refresh_token(self, token)
#      36
#      37     def __refresh_token(self, token):
# ---> 38         req_time = int(time.time())
#      39         r = request.urlopen(self.config['Auth']['RefreshURL'].format(token))
#      40         if r.getcode() == 200:
#
# C:\Program Files\Python39\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# C:\Program Files\Python39\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     521         for processor in self.process_response.get(protocol, []):
#     522             meth = getattr(processor, meth_name)
# --> 523             response = meth(req, response)
#     524
#     525         return response
#
# C:\Program Files\Python39\lib\urllib\request.py in http_response(self, request, response)
#     630         # request was successfully received, understood, and accepted.
#     631         if not (200 <= code < 300):
# --> 632             response = self.parent.error(
#     633                 'http', request, response, code, msg, hdrs)
#     634
#
# C:\Program Files\Python39\lib\urllib\request.py in error(self, proto, *args)
#     559         if http_err:
#     560             args = (dict, 'default', 'http_error_default') + orig_args
# --> 561             return self._call_chain(*args)
#     562
#     563 # XXX probably also want an abstract factory that knows when it makes
#
# C:\Program Files\Python39\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# C:\Program Files\Python39\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     639 class HTTPDefaultErrorHandler(BaseHandler):
#     640     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     642
#     643 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 400: Bad Request

# %%
# GET ACCOUNT ID

id = input('Enter Account ID :')
#id = '28231880'
print('Using Account: ',id)
# Out:
# Enter Account ID : 28148589
# Using Account:  28148589

# %%
# ACCOUNT POSITIONS
def account_positions():
    filename = os.path.join(filefolder, id+'-positions-'+time_name()+'.xlsx')
    dict_positions = q.account_positions(id)
    #print(dict_positions)
    position_list = dict_positions['positions']
    df_positions = pd.DataFrame.from_dict(position_list)
    display(df_positions)
    df_positions.to_excel(filename, header=True, )
    return('success')

account_positions()
# Out:
#      symbol  symbolId  openQuantity  closedQuantity  currentMarketValue  \
# 0      INPX  28504832         10000               0            10300.00
# 1     MT.VN  26639880         20000               0             2700.00
# 2      LQDA  22400523           400               0              936.00
# 3      TBLT  30099980          6000               0             3991.80
# 4      ABIO  25311505          2500               0             7550.00
# 5       NAT     44317          1000               0             2340.00
# 6      PBLA  33337897          2000               0             4760.00
# 7     ASTSW  35424817           100             100              330.00
# 8   NICL.VN  33002807         30000               0             2250.00
# 9     FLMNW  22771775          3000               0              272.40
# 10    NIKLF  33002818         10000               0              635.00
# 11  SKYG.VN  28114754          5000               0              525.00
# 12    CLVRW  33647952           350               0              752.50
# 13     CLVR  33647953           700             300             7672.00
# 14     LUMO  29650010           200               0             1480.00
# 15     BKYI  33213026          1000               0             3260.00
# 16      QSI  36486253          1000               0             8290.00
# 17     ASTC  19148407          2000               0             2220.00
# 18  BITK.VN  21751426          8000               0             4640.00
# 19     TPST  36787844            53               0              718.15
# 20   IMR.VN  32080019         10000               0              900.00
# 21   HUT.TO  20782742           800               0             7016.00
# 22    GOEVW  33688474           300             300              573.00
# 23     GOEV  33688475           600               0             4740.00
# 24      YVR  23327645          5000               0             9050.00
# 25     DFFN  24041638          9000               0             4779.00
# 26    TBLTW  23932327          5000               0             1000.00
# 27  IMCC.CN  34514093          1440               0             8784.00
# 28   AGL.VN  17605807         15000               0             3300.00
# 29  NUMI.VN  30630074          8000               0             7440.00
# 30   DML.TO     15815          3000               0             4170.00
# 31   WKG.VN  28117979         20000               0             3000.00
# 32   MDX.VN     27105         14000               0             1680.00
# 33      DSS  30459108          1000               0             1350.00
#
#     currentPrice  averageEntryPrice  dayPnl  closedPnl     openPnl  \
# 0         1.0300           1.079000 -100.00     0.0000  -490.00000
# 1         0.1350           0.122075    0.00     0.0000   258.50000
# 2         2.3400           3.003000  -28.00     0.0000  -265.20000
# 3         0.6653           0.690000   51.60     0.0000  -148.20000
# 4         3.0200           3.550000 -100.00     0.0000 -1325.00000
# 5         2.3400           3.540000  -20.00     0.0000 -1200.00000
# 6         2.3800           4.246970 -140.00     0.0000 -3733.94000
# 7         3.3000           2.655000  -19.00   264.5000    64.50000
# 8         0.0750           0.125000 -150.00     0.0000 -1500.00000
# 9         0.0908           0.180000  -27.60     0.0000  -267.60000
# 10        0.0635           0.094820  -24.60     0.0000  -313.20000
# 11        0.1050           0.220000    0.00     0.0000  -575.00000
# 12        2.1500           1.590000   -3.50     0.0000   196.00000
# 13       10.9600           8.400000  -28.00  1080.0000  1792.00000
# 14        7.4000          11.200000   -6.00     0.0000  -760.00000
# 15        3.2600           3.570000 -100.00     0.0000  -310.00000
# 16        8.2900           9.750000 -540.00     0.0000 -1460.00000
# 17        1.1100           1.228400  -40.00     0.0000  -236.80000
# 18        0.5800           0.550000  240.00     0.0000   240.00000
# 19       13.5500          13.360000   -5.30     0.0000    10.07000
# 20        0.0900           0.100000    0.00     0.0000  -100.00000
# 21        8.7700           5.260000  712.00     0.0000  2808.00000
# 22        1.9100           1.836667  -26.97   540.9999    21.99990
# 23        7.9000           7.998900  -54.00     0.0000   -59.34000
# 24        1.8100           1.880000 -550.00     0.0000  -350.00000
# 25        0.5310           0.790000 -342.90     0.0000 -2331.00000
# 26        0.2000           0.200000  -27.00     0.0000     0.00000
# 27        6.1000           5.146667 -230.40     0.0000  1372.79952
# 28        0.2200           0.300000   75.00     0.0000 -1200.00000
# 29        0.9300           0.999375    0.00     0.0000  -555.00000
# 30        1.3900           1.530000    0.00     0.0000  -420.00000
# 31        0.1500           0.170000    0.00     0.0000  -400.00000
# 32        0.1200           0.149857    0.00     0.0000  -417.99800
# 33        1.3500           2.850000   40.00     0.0000 -1500.00000
#
#       totalCost  isRealTime  isUnderReorg
# 0   10790.00000       False         False
# 1    2441.50000       False         False
# 2    1201.20000       False         False
# 3    4140.00000       False         False
# 4    8875.00000       False         False
# 5    3540.00000       False         False
# 6    8493.94000       False         False
# 7     265.50000       False         False
# 8    3750.00000       False         False
# 9     540.00000       False         False
# 10    948.20000       False         False
# 11   1100.00000       False         False
# 12    556.50000       False         False
# 13   5880.00000       False         False
# 14   2240.00000       False         False
# 15   3570.00000       False         False
# 16   9750.00000       False         False
# 17   2456.80000       False         False
# 18   4400.00000       False         False
# 19    708.08000       False         False
# 20   1000.00000       False         False
# 21   4208.00000       False         False
# 22    551.00010       False         False
# 23   4799.34000       False         False
# 24   9400.00000       False         False
# 25   7110.00000       False         False
# 26   1000.00000       False         False
# 27   7411.20048       False         False
# 28   4500.00000       False         False
# 29   7995.00000       False         False
# 30   4590.00000       False         False
# 31   3400.00000       False         False
# 32   2097.99800       False         False
# 33   2850.00000       False         False
# 'success'

# %%
# ACCOUNT BALANCES - COMBINED

def account_balances():
    filename = os.path.join(filefolder, id+'-balances-'+time_name()+'.xlsx')
    dict_balances = q.account_balances(id)
    #combined_balances1 = dict_balances['perCurrencyBalances']
    #combined_balances2 = dict_balances['combinedBalances']
    #combined_balances3 = dict_balances['sodPerCurrencyBalances']
    #combined_balances4 = dict_balances['sodCombinedBalances']
    df_combined_balances1 = pd.DataFrame.from_dict(dict_balances['perCurrencyBalances'])  #Per balances: True CAD and USD native amounts
    df_combined_balances2 = pd.DataFrame.from_dict(dict_balances['combinedBalances'])  #combined : each row is TOTAL value in that currency - could be used for the 3rd row : combined in CAD
    df_combined_balances3 = pd.DataFrame.from_dict(dict_balances['sodPerCurrencyBalances'])# sod per Currency balances : The MOST ACCURATE to what is shown in account.
    df_combined_balances4= pd.DataFrame.from_dict(dict_balances['sodCombinedBalances'])# sod combined balances : Combined totals of sod per currency for use in 3rd row
    #display(df_combined_balances1)
    #display(df_combined_balances2)
    display(df_combined_balances3)
    display(df_combined_balances4)
    df_combined_balances3.to_excel(r'D:\Dropbox\- INVESTINU\- QUESTRADE_API EXPORTS\ACCOUNT 2\combined_currency_balances.xlsx', header=True, )
    df_combined_balances4.to_excel(r'D:\Dropbox\- INVESTINU\- QUESTRADE_API EXPORTS\ACCOUNT 2\combined_total_balances.xlsx', header=True, )
    df_combined_balances3.to_excel(filename, header=True)
    df_combined_balances4.to_excel(filename, header=True)
    return('success')

account_balances()
# Out:
#   currency          cash  marketValue   totalEquity  buyingPower  \
# 0      CAD   7668.250000     45102.00  52770.250000  33868.26450
# 1      USD  14752.270006     79074.15  93826.420006  98334.13412
#
#    maintenanceExcess  isRealTime
# 0       10170.650000        True
# 1       29529.770006        True
#   currency          cash    marketValue    totalEquity    buyingPower  \
# 0      CAD  26138.829661  144106.789508  170245.619169  154278.291517
# 1      USD  20876.825735  115096.673062  135973.498797  124789.145554
#
#    maintenanceExcess  isRealTime
# 0       46329.817272        True
# 1       37474.217884        True
# 'success'

# %%
# ORDERS
def orders(start_time):
    filename = os.path.join(filefolder, id+'-orders-'+time_name()+'.xlsx')
    dict_orders = q.account_orders(id, startTime=start_time)
    df_orders = pd.DataFrame.from_dict(dict_orders['orders'])
    #display(df_orders)
    df_orders.to_excel(filename, header=True)
    return('success')

orders('2021-01-01T00:00:00-0')
# Out:
# 'success'

# %%
# INDIVIDUAL ORDER DETAIL
dict_order = q.account_order(id, 906251374)
dict_order['orders']
df_order = pd.DataFrame.from_dict(dict_order['orders'])
display(df_order)
# Out:
#           id  symbol  symbolId  totalQuantity  openQuantity  filledQuantity  \
# 0  906251374  HUT.TO  20782742            800             0             800
#
#    canceledQuantity side orderType  limitPrice  ... isInsider  \
# 0                 0  Buy     Limit        5.26  ...     False
#
#    isLimitOffsetInDollar   userId placementCommission legs  strategyType  \
# 0                  False  1292261                None   []     SingleLeg
#
#   triggerStopPrice orderGroupId orderClass isCrossZero
# 0             None            0       None       False
#
# [1 rows x 43 columns]

# %%
# EXECUTIONS
def executions(start_time):
    filename = os.path.join(filefolder, id+'-executions-'+time_name()+'.xlsx')
    #print(filepath)
    dict_executions = q.account_executions(id, startTime=start_time)
    #dict_executions
    df_executions = pd.DataFrame.from_dict(dict_executions['executions'])
    display(df_executions)
    df_executions.to_excel(filename, header=True, )
    return('success')

executions('2021-01-01T00:00:00-0')
# Out:
#      symbol  symbolId  quantity  side    price          id    orderId  \
# 0      BYSI  16887775      1000  Sell   9.0029  1143201941  908964115
# 1      NSPR  35790135      1000  Sell   4.0162  1141110026  907948920
# 2    WKG.VN  28117979      2500   Buy   0.2100  1138606592  906609002
# 3    AGL.VN  17605807     15000   Buy   0.3000  1138502585  906612944
# 4    WKG.VN  28117979      2500   Buy   0.2100  1138494642  906609002
# 5    WKG.VN  28117979      2500   Buy   0.2100  1138494644  906609002
# 6    WKG.VN  28117979       500   Buy   0.2100  1138494646  906609002
# 7    WKG.VN  28117979      2000   Buy   0.2100  1138494648  906609002
# 8    HUT.TO  20782742       100   Buy   5.2600  1137821947  906251374
# 9    HUT.TO  20782742       500   Buy   5.2600  1137821949  906251374
# 10   HUT.TO  20782742       200   Buy   5.2600  1137821951  906251374
# 11  DEFI.TO  34856813      1500  Sell   0.6800  1131769945  903240360
# 12  DEFI.TO  34856813      3000  Sell   0.6800  1131769941  903240360
# 13  DEFI.TO  34856813      1500  Sell   0.7000  1131769933  903240360
# 14  DEFI.TO  34856813      1000  Sell   0.7000  1131769935  903240360
# 15  DEFI.TO  34856813       500  Sell   0.7000  1131769937  903240360
# 16  DEFI.TO  34856813       500  Sell   0.6800  1131769939  903240360
# 17  WEED.TO  16529510       400  Sell  26.0000  1130403296  902576210
# 18  HEXO.TO  33701175      1000  Sell   6.1000  1126570163  900723524
#
#     orderChainId exchangeExecId                         timestamp notes  \
# 0      876165798      231896325  2021-07-27T13:56:21.000000-04:00
# 1      875132200      206000138  2021-07-26T09:50:24.000000-04:00
# 2      906609002       S3-19654  2021-07-22T10:51:05.000000-04:00
# 3      906612944       S3-15857  2021-07-22T10:21:17.000000-04:00
# 4      906609002       S3-15523  2021-07-22T10:18:21.000000-04:00
# 5      906609002       S3-15524  2021-07-22T10:18:21.000000-04:00
# 6      906609002       S3-15525  2021-07-22T10:18:21.000000-04:00
# 7      906609002       S3-15526  2021-07-22T10:18:21.000000-04:00
# 8      906251374       S3-43995  2021-07-21T14:32:20.000000-04:00
# 9      906251374       S3-43996  2021-07-21T14:32:20.000000-04:00
# 10     906251374       S3-43997  2021-07-21T14:32:20.000000-04:00
# 11     875994670       S3-47505  2021-07-15T13:48:14.000000-04:00
# 12     875994670       S3-47503  2021-07-15T13:48:14.000000-04:00
# 13     875994670       S3-47499  2021-07-15T13:48:14.000000-04:00
# 14     875994670       S3-47500  2021-07-15T13:48:14.000000-04:00
# 15     875994670       S3-47501  2021-07-15T13:48:14.000000-04:00
# 16     875994670       S3-47502  2021-07-15T13:48:14.000000-04:00
# 17     873497653       S3-51115  2021-07-14T14:28:18.000000-04:00
# 18     874644477       S3-14305  2021-07-12T09:45:49.000000-04:00
#
#      venue  totalCost  orderPlacementCommission  commission  executionFee  \
# 0   CTDLBN     9002.9                         0        9.95           0.0
# 1   CTDLBN     4016.2                         0        9.95           0.0
# 2     TSXV      525.0                         0        0.00           0.0
# 3     TSXV     4500.0                         0        9.95          12.0
# 4      OME      525.0                         0        9.95           2.0
# 5      CX2      525.0                         0        0.00           2.0
# 6      AQN      105.0                         0        0.00           0.4
# 7     TSXV      420.0                         0        0.00           1.6
# 8      TSX      526.0                         0        4.95           0.0
# 9      TSX     2630.0                         0        1.05           0.0
# 10     TSX     1052.0                         0        2.00           0.0
# 11     AQL     1020.0                         0        0.00           0.0
# 12     AQL     2040.0                         0        0.00           0.0
# 13     AQL     1050.0                         0        9.95           1.2
# 14     AQL      700.0                         0        0.00           0.8
# 15     AQL      350.0                         0        0.00           0.4
# 16     AQL      340.0                         0        0.00           0.4
# 17    ALPH    10400.0                         0        4.95           1.4
# 18    ALPH     6100.0                         0        9.95           3.5
#
#       secFee  legId  canadianExecutionFee    parentId
# 0   0.045915      0                     0  1143201941
# 1   0.020483      0                     0  1141110026
# 2   0.000000      0                     0  1138606592
# 3   0.000000      0                     0  1138502585
# 4   0.000000      0                     0  1138494642
# 5   0.000000      0                     0  1138494644
# 6   0.000000      0                     0  1138494646
# 7   0.000000      0                     0  1138494648
# 8   0.000000      0                     0  1137821947
# 9   0.000000      0                     0  1137821949
# 10  0.000000      0                     0  1137821951
# 11  0.000000      0                     0  1131769945
# 12  0.000000      0                     0  1131769941
# 13  0.000000      0                     0  1131769933
# 14  0.000000      0                     0  1131769935
# 15  0.000000      0                     0  1131769937
# 16  0.000000      0                     0  1131769939
# 17  0.000000      0                     0  1130403296
# 18  0.000000      0                     0  1126570163
# 'success'

# %%
# ACCOUNT ACTIVITIES --- only 30 days
def activities():
    filename = os.path.join(filefolder, id+'-activities-'+time_name()+'.xlsx')
    dict_activities = q.account_activities(id, startTime=start_date(30))
    #print(dict_activities)
    df_activities = pd.DataFrame.from_dict(dict_activities['activities'])
    display(df_activities)
    df_activities.to_excel(filename, header=True, )
    return('success')

activities()
# Out:
#                            tradeDate                   transactionDate  \
# 0   2021-07-12T00:00:00.000000-04:00  2021-07-14T00:00:00.000000-04:00
# 1   2021-07-14T00:00:00.000000-04:00  2021-07-16T00:00:00.000000-04:00
# 2   2021-07-15T00:00:00.000000-04:00  2021-07-19T00:00:00.000000-04:00
# 3   2021-07-21T00:00:00.000000-04:00  2021-07-23T00:00:00.000000-04:00
# 4   2021-07-22T00:00:00.000000-04:00  2021-07-26T00:00:00.000000-04:00
# 5   2021-07-22T00:00:00.000000-04:00  2021-07-26T00:00:00.000000-04:00
# 6   2021-07-22T00:00:00.000000-04:00  2021-07-26T00:00:00.000000-04:00
# 7   2021-07-22T00:00:00.000000-04:00  2021-07-26T00:00:00.000000-04:00
# 8   2021-07-22T00:00:00.000000-04:00  2021-07-26T00:00:00.000000-04:00
# 9   2021-07-26T00:00:00.000000-04:00  2021-07-28T00:00:00.000000-04:00
# 10  2021-07-27T00:00:00.000000-04:00  2021-07-29T00:00:00.000000-04:00
# 11  2021-07-14T00:00:00.000000-04:00  2021-07-14T00:00:00.000000-04:00
# 12  2021-07-14T00:00:00.000000-04:00  2021-07-14T00:00:00.000000-04:00
# 13  2021-07-20T00:00:00.000000-04:00  2021-07-20T00:00:00.000000-04:00
# 14  2021-07-20T00:00:00.000000-04:00  2021-07-20T00:00:00.000000-04:00
# 15  2021-07-16T00:00:00.000000-04:00  2021-07-16T00:00:00.000000-04:00
#
#                       settlementDate action   symbol  symbolId  \
# 0   2021-07-14T00:00:00.000000-04:00   Sell  HEXO.TO  33701175
# 1   2021-07-16T00:00:00.000000-04:00   Sell  WEED.TO  16529510
# 2   2021-07-19T00:00:00.000000-04:00   Sell  DEFI.TO  34856813
# 3   2021-07-23T00:00:00.000000-04:00    Buy   HUT.TO  20782742
# 4   2021-07-26T00:00:00.000000-04:00    Buy   AGL.VN  17605807
# 5   2021-07-26T00:00:00.000000-04:00    Buy   WKG.VN  28117979
# 6   2021-07-26T00:00:00.000000-04:00    Buy   WKG.VN  28117979
# 7   2021-07-26T00:00:00.000000-04:00    Buy   WKG.VN  28117979
# 8   2021-07-26T00:00:00.000000-04:00    Buy   WKG.VN  28117979
# 9   2021-07-28T00:00:00.000000-04:00   Sell     NSPR  35790135
# 10  2021-07-29T00:00:00.000000-04:00   Sell     BYSI  16887775
# 11  2021-07-14T00:00:00.000000-04:00    MGR  IMCC.CN  34514093
# 12  2021-07-14T00:00:00.000000-04:00    MGR   MYM.CN  13022458
# 13  2021-07-20T00:00:00.000000-04:00    FXT                  0
# 14  2021-07-20T00:00:00.000000-04:00    FXT                  0
# 15  2021-07-16T00:00:00.000000-04:00                         0
#
#                                           description currency  quantity  \
# 0               HEXO CORP  COM NEW  WE ACTED AS AGENT      CAD     -1000
# 1   CANOPY GROWTH CORPORATION  COMMON SHARES  WE A...      CAD      -400
# 2   DEFI TECHNOLOGIES INC  COM  WE ACTED AS AGENT ...      CAD     -8000
# 3   HUT 8 MINING CORP NEW  COMMON  WE ACTED AS AGE...      CAD       800
# 4   AGUILA AMERN GOLD LTD  COM NO PAR  WE ACTED AS...      CAD     15000
# 5       WESTKAM GOLD CORP  COM NEW  WE ACTED AS AGENT      CAD      2500
# 6       WESTKAM GOLD CORP  COM NEW  WE ACTED AS AGENT      CAD      2500
# 7       WESTKAM GOLD CORP  COM NEW  WE ACTED AS AGENT      CAD       500
# 8   WESTKAM GOLD CORP  COM NEW  WE ACTED AS AGENT ...      CAD      4500
# 9      INSPIREMD INC  COMMON STOCK  WE ACTED AS AGENT      USD     -1000
# 10  BEYONDSPRING INC  ORDINARY SHARES  WE ACTED AS...      USD     -1000
# 11  IM CANNABIS CORP COM NEW SHRS RECEIVED THRU ME...      CAD       440
# 12  MYM NUTRACEUTICALS INC COM PLAN OF ARRANGEMENT...      CAD    -20000
# 13                               CONVERSION - CAD/USD      CAD         0
# 14                               CONVERSION - CAD/USD      USD         0
# 15  INT FR 06/16 THRU07/15@ 6    % BAL   97,718   ...      USD         0
#
#       price  grossAmount  commission  netAmount               type
# 0    6.1000       6100.0      -13.45    6086.55             Trades
# 1   26.0000      10400.0       -6.35   10393.65             Trades
# 2    0.6875       5500.0      -12.75    5487.25             Trades
# 3    5.2600      -4208.0       -8.00   -4216.00             Trades
# 4    0.3000      -4500.0      -21.95   -4521.95             Trades
# 5    0.2100       -525.0       -2.00    -527.00             Trades
# 6    0.2100       -525.0      -11.95    -536.95             Trades
# 7    0.2100       -105.0       -0.40    -105.40             Trades
# 8    0.2100       -945.0       -1.60    -946.60             Trades
# 9    4.0162       4016.2       -9.98    4006.22             Trades
# 10   9.0029       9002.9      -10.00    8992.90             Trades
# 11   0.0000          0.0        0.00       0.00  Corporate actions
# 12   0.0000          0.0        0.00       0.00  Corporate actions
# 13   0.0000          0.0        0.00 -128820.00      FX conversion
# 14   0.0000          0.0        0.00  100000.00      FX conversion
# 15   0.0000          0.0        0.00    -528.04           Interest
# 'success'

# %%
# SYMBOL - uses symbole idonly

dict_symbol = q.symbol(34231109)
dict_symbol
df_symbol = pd.DataFrame.from_dict(dict_symbol['symbols'])
display(df_symbol)
# Out:
#   symbol  symbolId  prevDayClosePrice  highPrice52  lowPrice52  \
# 0   XELA  34231109               3.22         7.82      0.9903
#
#    averageVol3Months  averageVol20Days  outstandingShares    eps    pe  ...  \
# 0           65663583         103516254           59192000 -11.51  None  ...
#
#                        dividendDate  optionStrikePrice isTradable  isQuotable  \
# 0  2021-01-26T00:00:00.000000-05:00               None       True        True
#
#    hasOptions currency                                           minTicks  \
# 0        True      USD  [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1,...
#
#   industrySector industryGroup industrySubgroup
# 0     Technology     Undefined        Undefined
#
# [1 rows x 34 columns]

# %%
# SYMBOLs - can use symbols or id

dict_symbols = q.symbols(ids='34231109,34856813')
dict_symbols
df_symbols = pd.DataFrame.from_dict(dict_symbols['symbols'])
display(df_symbols)
# Out:
#     symbol  symbolId  prevDayClosePrice  highPrice52  lowPrice52  \
# 0     XELA  34231109               3.22         7.82      0.9903
# 1  DEFI.TO  34856813               1.14          NaN         NaN
#
#    averageVol3Months  averageVol20Days  outstandingShares    eps    pe  ...  \
# 0           65663583         103516254         59192000.0 -11.51  None  ...
# 1             524421            631095                NaN    NaN  None  ...
#
#                        dividendDate  optionStrikePrice isTradable  isQuotable  \
# 0  2021-01-26T00:00:00.000000-05:00               None       True        True
# 1                              None               None       True        True
#
#    hasOptions currency                                           minTicks  \
# 0        True      USD  [{'pivot': 0, 'minTick': 0.0001}, {'pivot': 1,...
# 1       False      CAD  [{'pivot': 0, 'minTick': 0.005}, {'pivot': 0.5...
#
#       industrySector industryGroup industrySubgroup
# 0         Technology     Undefined        Undefined
# 1  FinancialServices     Undefined        Undefined
#
# [2 rows x 34 columns]
